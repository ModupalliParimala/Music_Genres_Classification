# %% [markdown]
# <a href="https://colab.research.google.com/github/ModupalliParimala/Music_Genres_Classification/blob/main/Music_Genres_classification_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Deep_Learning/Projects/
# Out:
# /content/gdrive/MyDrive/Deep_Learning/Projects

# %%
# %tensorflow_version 2.x

# %%
import pandas as pd
import numpy as np
from numpy import argmax
import librosa
import librosa.display
import IPython.display
import random
import warnings
import os
from PIL import Image
import csv
# sklearn Preprocessing
from sklearn.model_selection import train_test_split
#Keras
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization,Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential, Model,model_from_json
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas

# %%
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
for g in genres:
    os.makedirs(os.path.join("/content/gdrive/MyDrive/Deep_Learning/Projects",f'img_data/{g}'),exist_ok=True)
    for filename in os.listdir(f'./genres/{g}'):
        song = f'./genres/{g}/{filename}'
        y,sr = librosa.load(song,sr=None)
        mels = librosa.feature.melspectrogram(y=y,sr=sr)
        fig = plt.Figure()
        canvas = FigureCanvas(fig)
        librosa.display.specshow(librosa.power_to_db(mels,ref=np.max))
        plt.savefig(f'img_data/{g}/{filename[:-3].replace(".", "")}.jpg')
        plt.close()    
        fig.clf()
        plt.close(fig)
        plt.close('all')
    
del g,filename,song,y,sr,fig,canvas

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading https://files.pythonhosted.org/packages/b8/5f/3c2b2f7ea5e047c8cdc3bb00ae582c5438fcdbbedcc23b3cc1c2c7aae642/split_folders-0.4.3-py3-none-any.whl
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %%
import splitfolders 
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio('./img_data/', output="./data", seed=1337, ratio=(.8, .2)) # default value
# Out:
# Copying files: 1000 files [04:45,  3.50 files/s]

# %%
#Data augmentation is not required in case spectrogram.just standardizing image data by dividing by 255
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255 # rescale all pixel values from 0-255, so aftre this step all our pixel values are in range (0,1)
        ) 
test_datagen = ImageDataGenerator(
        rescale=1./255 # rescale all pixel values from 0-255, so aftre this step all our pixel values are in range (0,1)
        )

# %%
training_set = train_datagen.flow_from_directory(
        './data/train',
        target_size=(64, 64),
        batch_size=40,
        class_mode='categorical')
test_set = test_datagen.flow_from_directory(
        './data/val',
        target_size=(64, 64),
        batch_size=40,
        class_mode='categorical' )
# Out:
# Found 800 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.

# %%
input_shape=(64, 64, 3)

model = Sequential()
model.add(Conv2D(16, (3, 3), padding='same',
                 input_shape=input_shape,
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(32, (3, 3),padding='same',kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same',kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3),padding='same',kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(256, (3, 3),padding='same',kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(512, (3, 3),padding='same',kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
outputFolder="./output"
# Model weights are saved at the end of every epoch, if it's the best seen so far.
filepath=outputFolder+"/weights-{epoch:02d}-{accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='accuracy', 
                             verbose=1, 
                             save_best_only=True, 
                             save_weights_only=True, 
                             mode='auto')

# %%
#Early Stopping
earlystop = EarlyStopping(monitor='loss', 
                          min_delta=0.01, patience=5,
                          verbose=1, mode='auto')

# %%
# if the accuracy does not increase over 10 epochs, reduce the learning rate by half.
reduce_lr = ReduceLROnPlateau(monitor='accuracy', factor=0.5, patience=10, min_lr=0.0001, verbose=1)
model.fit(
        training_set,
        epochs=200,
        verbose = 1,
        steps_per_epoch=training_set.n//training_set.batch_size,
        validation_data=test_set,
        validation_steps=test_set.n//test_set.batch_size,
        callbacks=[reduce_lr,checkpoint])
# Out:
# Epoch 1/200
# 20/20 [==============================] - 4s 200ms/step - loss: 2.1483 - accuracy: 0.3113 - val_loss: 3.4035 - val_accuracy: 0.1000
#
# Epoch 00001: accuracy improved from 0.28625 to 0.31125, saving model to ./output/weights-01-0.3113.h5
# Epoch 2/200
# 20/20 [==============================] - 4s 200ms/step - loss: 1.9045 - accuracy: 0.3887 - val_loss: 3.7606 - val_accuracy: 0.1000
#
# Epoch 00002: accuracy improved from 0.31125 to 0.38875, saving model to ./output/weights-02-0.3887.h5
# Epoch 3/200
# 20/20 [==============================] - 4s 202ms/step - loss: 1.7754 - accuracy: 0.4100 - val_loss: 3.9702 - val_accuracy: 0.1100
#
# Epoch 00003: accuracy improved from 0.38875 to 0.41000, saving model to ./output/weights-03-0.4100.h5
# Epoch 4/200
# 20/20 [==============================] - 4s 202ms/step - loss: 1.7904 - accuracy: 0.4125 - val_loss: 4.5756 - val_accuracy: 0.1400
#
# Epoch 00004: accuracy improved from 0.41000 to 0.41250, saving model to ./output/weights-04-0.4125.h5
# Epoch 5/200
# 20/20 [==============================] - 4s 202ms/step - loss: 1.7115 - accuracy: 0.4462 - val_loss: 4.5746 - val_accuracy: 0.1000
#
# Epoch 00005: accuracy improved from 0.41250 to 0.44625, saving model to ./output/weights-05-0.4462.h5
# Epoch 6/200
# 20/20 [==============================] - 4s 201ms/step - loss: 1.5621 - accuracy: 0.4750 - val_loss: 5.1284 - val_accuracy: 0.1000
#
# Epoch 00006: accuracy improved from 0.44625 to 0.47500, saving model to ./output/weights-06-0.4750.h5
# Epoch 7/200
# 20/20 [==============================] - 4s 201ms/step - loss: 1.6795 - accuracy: 0.4300 - val_loss: 5.9138 - val_accuracy: 0.1000
#
# Epoch 00007: accuracy did not improve from 0.47500
# Epoch 8/200
# 20/20 [==============================] - 4s 201ms/step - loss: 1.5607 - accuracy: 0.4812 - val_loss: 6.5967 - val_accuracy: 0.1000
#
# Epoch 00008: accuracy improved from 0.47500 to 0.48125, saving model to ./output/weights-08-0.4812.h5
# Epoch 9/200
# 20/20 [==============================] - 4s 199ms/step - loss: 1.4090 - accuracy: 0.5312 - val_loss: 6.8388 - val_accuracy: 0.1000
#
# Epoch 00009: accuracy improved from 0.48125 to 0.53125, saving model to ./output/weights-09-0.5312.h5
# Epoch 10/200
# 20/20 [==============================] - 4s 204ms/step - loss: 1.3519 - accuracy: 0.5350 - val_loss: 7.5072 - val_accuracy: 0.1000
#
# Epoch 00010: accuracy improved from 0.53125 to 0.53500, saving model to ./output/weights-10-0.5350.h5
# Epoch 11/200
# 20/20 [==============================] - 4s 201ms/step - loss: 1.3716 - accuracy: 0.5663 - val_loss: 6.6722 - val_accuracy: 0.1000
#
# Epoch 00011: accuracy improved from 0.53500 to 0.56625, saving model to ./output/weights-11-0.5663.h5
# Epoch 12/200
# 20/20 [==============================] - 4s 203ms/step - loss: 1.3368 - accuracy: 0.5788 - val_loss: 6.8340 - val_accuracy: 0.1000
#
# Epoch 00012: accuracy improved from 0.56625 to 0.57875, saving model to ./output/weights-12-0.5788.h5
# Epoch 13/200
# 20/20 [==============================] - 4s 200ms/step - loss: 1.2423 - accuracy: 0.5850 - val_loss: 6.3641 - val_accuracy: 0.1750
#
# Epoch 00013: accuracy improved from 0.57875 to 0.58500, saving model to ./output/weights-13-0.5850.h5
# Epoch 14/200
# 20/20 [==============================] - 4s 202ms/step - loss: 1.2085 - accuracy: 0.6062 - val_loss: 6.2939 - val_accuracy: 0.1000
#
# Epoch 00014: accuracy improved from 0.58500 to 0.60625, saving model to ./output/weights-14-0.6062.h5
# Epoch 15/200
# 20/20 [==============================] - 4s 204ms/step - loss: 1.1955 - accuracy: 0.6012 - val_loss: 6.2034 - val_accuracy: 0.1000
#
# Epoch 00015: accuracy did not improve from 0.60625
# Epoch 16/200
# 20/20 [==============================] - 4s 199ms/step - loss: 1.1803 - accuracy: 0.6200 - val_loss: 6.5782 - val_accuracy: 0.1650
#
# Epoch 00016: accuracy improved from 0.60625 to 0.62000, saving model to ./output/weights-16-0.6200.h5
# Epoch 17/200
# 20/20 [==============================] - 4s 200ms/step - loss: 1.1307 - accuracy: 0.6162 - val_loss: 5.9145 - val_accuracy: 0.1500
#
# Epoch 00017: accuracy did not improve from 0.62000
# Epoch 18/200
# 20/20 [==============================] - 4s 199ms/step - loss: 1.1622 - accuracy: 0.6237 - val_loss: 5.5399 - val_accuracy: 0.1150
#
# Epoch 00018: accuracy improved from 0.62000 to 0.62375, saving model to ./output/weights-18-0.6237.h5
# Epoch 19/200
# 20/20 [==============================] - 4s 205ms/step - loss: 1.0985 - accuracy: 0.6513 - val_loss: 5.6487 - val_accuracy: 0.1450
#
# Epoch 00019: accuracy improved from 0.62375 to 0.65125, saving model to ./output/weights-19-0.6513.h5
# Epoch 20/200
# 20/20 [==============================] - 4s 200ms/step - loss: 1.0451 - accuracy: 0.6625 - val_loss: 4.9575 - val_accuracy: 0.1150
#
# Epoch 00020: accuracy improved from 0.65125 to 0.66250, saving model to ./output/weights-20-0.6625.h5
# Epoch 21/200
# 20/20 [==============================] - 4s 203ms/step - loss: 1.0549 - accuracy: 0.6562 - val_loss: 5.4376 - val_accuracy: 0.1050
#
# Epoch 00021: accuracy did not improve from 0.66250
# Epoch 22/200
# 20/20 [==============================] - 4s 201ms/step - loss: 1.0187 - accuracy: 0.6712 - val_loss: 4.0871 - val_accuracy: 0.2100
#
# Epoch 00022: accuracy improved from 0.66250 to 0.67125, saving model to ./output/weights-22-0.6712.h5
# Epoch 23/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.9651 - accuracy: 0.6762 - val_loss: 4.3404 - val_accuracy: 0.1900
#
# Epoch 00023: accuracy improved from 0.67125 to 0.67625, saving model to ./output/weights-23-0.6762.h5
# Epoch 24/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.9431 - accuracy: 0.7150 - val_loss: 3.7488 - val_accuracy: 0.2700
#
# Epoch 00024: accuracy improved from 0.67625 to 0.71500, saving model to ./output/weights-24-0.7150.h5
# Epoch 25/200
# 20/20 [==============================] - 4s 205ms/step - loss: 0.9032 - accuracy: 0.7088 - val_loss: 3.9889 - val_accuracy: 0.1800
#
# Epoch 00025: accuracy did not improve from 0.71500
# Epoch 26/200
# 20/20 [==============================] - 4s 198ms/step - loss: 0.9010 - accuracy: 0.7038 - val_loss: 3.4475 - val_accuracy: 0.2450
#
# Epoch 00026: accuracy did not improve from 0.71500
# Epoch 27/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.9183 - accuracy: 0.7163 - val_loss: 4.8511 - val_accuracy: 0.2000
#
# Epoch 00027: accuracy improved from 0.71500 to 0.71625, saving model to ./output/weights-27-0.7163.h5
# Epoch 28/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.8026 - accuracy: 0.7387 - val_loss: 4.5070 - val_accuracy: 0.2400
#
# Epoch 00028: accuracy improved from 0.71625 to 0.73875, saving model to ./output/weights-28-0.7387.h5
# Epoch 29/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.8083 - accuracy: 0.7513 - val_loss: 3.7567 - val_accuracy: 0.2850
#
# Epoch 00029: accuracy improved from 0.73875 to 0.75125, saving model to ./output/weights-29-0.7513.h5
# Epoch 30/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.8593 - accuracy: 0.7138 - val_loss: 2.9447 - val_accuracy: 0.3250
#
# Epoch 00030: accuracy did not improve from 0.75125
# Epoch 31/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.8105 - accuracy: 0.7437 - val_loss: 3.5255 - val_accuracy: 0.2600
#
# Epoch 00031: accuracy did not improve from 0.75125
# Epoch 32/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.8277 - accuracy: 0.7287 - val_loss: 3.6407 - val_accuracy: 0.2400
#
# Epoch 00032: accuracy did not improve from 0.75125
# Epoch 33/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.8066 - accuracy: 0.7563 - val_loss: 3.8958 - val_accuracy: 0.2650
#
# Epoch 00033: accuracy improved from 0.75125 to 0.75625, saving model to ./output/weights-33-0.7563.h5
# Epoch 34/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.8328 - accuracy: 0.7275 - val_loss: 2.6362 - val_accuracy: 0.3600
#
# Epoch 00034: accuracy did not improve from 0.75625
# Epoch 35/200
# 20/20 [==============================] - 4s 205ms/step - loss: 0.7423 - accuracy: 0.7688 - val_loss: 1.7143 - val_accuracy: 0.4450
#
# Epoch 00035: accuracy improved from 0.75625 to 0.76875, saving model to ./output/weights-35-0.7688.h5
# Epoch 36/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.7403 - accuracy: 0.7925 - val_loss: 2.1952 - val_accuracy: 0.4650
#
# Epoch 00036: accuracy improved from 0.76875 to 0.79250, saving model to ./output/weights-36-0.7925.h5
# Epoch 37/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.7444 - accuracy: 0.7812 - val_loss: 2.2806 - val_accuracy: 0.4150
#
# Epoch 00037: accuracy did not improve from 0.79250
# Epoch 38/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.6306 - accuracy: 0.8075 - val_loss: 2.4752 - val_accuracy: 0.3950
#
# Epoch 00038: accuracy improved from 0.79250 to 0.80750, saving model to ./output/weights-38-0.8075.h5
# Epoch 39/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.6902 - accuracy: 0.7700 - val_loss: 3.7886 - val_accuracy: 0.2650
#
# Epoch 00039: accuracy did not improve from 0.80750
# Epoch 40/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.6606 - accuracy: 0.8000 - val_loss: 2.2989 - val_accuracy: 0.4300
#
# Epoch 00040: accuracy did not improve from 0.80750
# Epoch 41/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.6164 - accuracy: 0.8062 - val_loss: 1.5639 - val_accuracy: 0.5650
#
# Epoch 00041: accuracy did not improve from 0.80750
# Epoch 42/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.5933 - accuracy: 0.8225 - val_loss: 2.1411 - val_accuracy: 0.4300
#
# Epoch 00042: accuracy improved from 0.80750 to 0.82250, saving model to ./output/weights-42-0.8225.h5
# Epoch 43/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.5832 - accuracy: 0.8200 - val_loss: 2.0771 - val_accuracy: 0.4350
#
# Epoch 00043: accuracy did not improve from 0.82250
# Epoch 44/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.5417 - accuracy: 0.8275 - val_loss: 2.2851 - val_accuracy: 0.4700
#
# Epoch 00044: accuracy improved from 0.82250 to 0.82750, saving model to ./output/weights-44-0.8275.h5
# Epoch 45/200
# 20/20 [==============================] - 4s 208ms/step - loss: 0.5726 - accuracy: 0.8300 - val_loss: 2.2607 - val_accuracy: 0.4300
#
# Epoch 00045: accuracy improved from 0.82750 to 0.83000, saving model to ./output/weights-45-0.8300.h5
# Epoch 46/200
# 20/20 [==============================] - 4s 208ms/step - loss: 0.5612 - accuracy: 0.8163 - val_loss: 2.7004 - val_accuracy: 0.3850
#
# Epoch 00046: accuracy did not improve from 0.83000
# Epoch 47/200
# 20/20 [==============================] - 4s 207ms/step - loss: 0.6063 - accuracy: 0.8100 - val_loss: 2.1964 - val_accuracy: 0.4450
#
# Epoch 00047: accuracy did not improve from 0.83000
# Epoch 48/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.4365 - accuracy: 0.8800 - val_loss: 2.0324 - val_accuracy: 0.4750
#
# Epoch 00048: accuracy improved from 0.83000 to 0.88000, saving model to ./output/weights-48-0.8800.h5
# Epoch 49/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.4681 - accuracy: 0.8637 - val_loss: 2.1610 - val_accuracy: 0.4700
#
# Epoch 00049: accuracy did not improve from 0.88000
# Epoch 50/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.5167 - accuracy: 0.8487 - val_loss: 2.5792 - val_accuracy: 0.3950
#
# Epoch 00050: accuracy did not improve from 0.88000
# Epoch 51/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.5224 - accuracy: 0.8537 - val_loss: 4.2803 - val_accuracy: 0.2550
#
# Epoch 00051: accuracy did not improve from 0.88000
# Epoch 52/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.4992 - accuracy: 0.8537 - val_loss: 2.6820 - val_accuracy: 0.4000
#
# Epoch 00052: accuracy did not improve from 0.88000
# Epoch 53/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.4598 - accuracy: 0.8825 - val_loss: 1.8585 - val_accuracy: 0.5100
#
# Epoch 00053: accuracy improved from 0.88000 to 0.88250, saving model to ./output/weights-53-0.8825.h5
# Epoch 54/200
# 20/20 [==============================] - 4s 198ms/step - loss: 0.4598 - accuracy: 0.8763 - val_loss: 1.6781 - val_accuracy: 0.5150
#
# Epoch 00054: accuracy did not improve from 0.88250
# Epoch 55/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.4804 - accuracy: 0.8662 - val_loss: 2.5428 - val_accuracy: 0.3800
#
# Epoch 00055: accuracy did not improve from 0.88250
# Epoch 56/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.4346 - accuracy: 0.8838 - val_loss: 2.6902 - val_accuracy: 0.4800
#
# Epoch 00056: accuracy improved from 0.88250 to 0.88375, saving model to ./output/weights-56-0.8838.h5
# Epoch 57/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.4308 - accuracy: 0.8950 - val_loss: 2.1414 - val_accuracy: 0.5000
#
# Epoch 00057: accuracy improved from 0.88375 to 0.89500, saving model to ./output/weights-57-0.8950.h5
# Epoch 58/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.4180 - accuracy: 0.8863 - val_loss: 2.0033 - val_accuracy: 0.4850
#
# Epoch 00058: accuracy did not improve from 0.89500
# Epoch 59/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.3672 - accuracy: 0.9125 - val_loss: 2.2039 - val_accuracy: 0.4900
#
# Epoch 00059: accuracy improved from 0.89500 to 0.91250, saving model to ./output/weights-59-0.9125.h5
# Epoch 60/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.3539 - accuracy: 0.9175 - val_loss: 3.4367 - val_accuracy: 0.3800
#
# Epoch 00060: accuracy improved from 0.91250 to 0.91750, saving model to ./output/weights-60-0.9175.h5
# Epoch 61/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.4250 - accuracy: 0.9000 - val_loss: 1.6730 - val_accuracy: 0.6100
#
# Epoch 00061: accuracy did not improve from 0.91750
# Epoch 62/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.4334 - accuracy: 0.8788 - val_loss: 2.5729 - val_accuracy: 0.3950
#
# Epoch 00062: accuracy did not improve from 0.91750
# Epoch 63/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.3702 - accuracy: 0.9075 - val_loss: 2.0095 - val_accuracy: 0.5200
#
# Epoch 00063: accuracy did not improve from 0.91750
# Epoch 64/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.4294 - accuracy: 0.8863 - val_loss: 1.9252 - val_accuracy: 0.5200
#
# Epoch 00064: accuracy did not improve from 0.91750
# Epoch 65/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.4361 - accuracy: 0.8763 - val_loss: 2.4385 - val_accuracy: 0.4650
#
# Epoch 00065: accuracy did not improve from 0.91750
# Epoch 66/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.3804 - accuracy: 0.9137 - val_loss: 2.3675 - val_accuracy: 0.5150
#
# Epoch 00066: accuracy did not improve from 0.91750
# Epoch 67/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.3682 - accuracy: 0.9125 - val_loss: 3.1821 - val_accuracy: 0.3600
#
# Epoch 00067: accuracy did not improve from 0.91750
# Epoch 68/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.3672 - accuracy: 0.9212 - val_loss: 1.5583 - val_accuracy: 0.6200
#
# Epoch 00068: accuracy improved from 0.91750 to 0.92125, saving model to ./output/weights-68-0.9212.h5
# Epoch 69/200
# 20/20 [==============================] - 4s 207ms/step - loss: 0.3338 - accuracy: 0.9187 - val_loss: 1.9830 - val_accuracy: 0.4900
#
# Epoch 00069: accuracy did not improve from 0.92125
# Epoch 70/200
# 20/20 [==============================] - 4s 205ms/step - loss: 0.3731 - accuracy: 0.9062 - val_loss: 2.1256 - val_accuracy: 0.5600
#
# Epoch 00070: accuracy did not improve from 0.92125
# Epoch 71/200
# 20/20 [==============================] - 4s 207ms/step - loss: 0.3653 - accuracy: 0.9175 - val_loss: 2.2722 - val_accuracy: 0.4900
#
# Epoch 00071: accuracy did not improve from 0.92125
# Epoch 72/200
# 20/20 [==============================] - 4s 198ms/step - loss: 0.2830 - accuracy: 0.9525 - val_loss: 1.6357 - val_accuracy: 0.5950
#
# Epoch 00072: accuracy improved from 0.92125 to 0.95250, saving model to ./output/weights-72-0.9525.h5
# Epoch 73/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.2852 - accuracy: 0.9425 - val_loss: 2.0097 - val_accuracy: 0.5750
#
# Epoch 00073: accuracy did not improve from 0.95250
# Epoch 74/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.3549 - accuracy: 0.9212 - val_loss: 2.0731 - val_accuracy: 0.5050
#
# Epoch 00074: accuracy did not improve from 0.95250
# Epoch 75/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.3240 - accuracy: 0.9287 - val_loss: 1.6413 - val_accuracy: 0.5900
#
# Epoch 00075: accuracy did not improve from 0.95250
# Epoch 76/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.3438 - accuracy: 0.9325 - val_loss: 2.3789 - val_accuracy: 0.4500
#
# Epoch 00076: accuracy did not improve from 0.95250
# Epoch 77/200
# 20/20 [==============================] - 4s 198ms/step - loss: 0.3128 - accuracy: 0.9413 - val_loss: 2.5488 - val_accuracy: 0.4950
#
# Epoch 00077: accuracy did not improve from 0.95250
# Epoch 78/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.2826 - accuracy: 0.9350 - val_loss: 2.1100 - val_accuracy: 0.5100
#
# Epoch 00078: accuracy did not improve from 0.95250
# Epoch 79/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.2935 - accuracy: 0.9300 - val_loss: 1.8925 - val_accuracy: 0.5350
#
# Epoch 00079: accuracy did not improve from 0.95250
# Epoch 80/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.3032 - accuracy: 0.9413 - val_loss: 1.7569 - val_accuracy: 0.5750
#
# Epoch 00080: accuracy did not improve from 0.95250
# Epoch 81/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.2918 - accuracy: 0.9300 - val_loss: 1.9547 - val_accuracy: 0.5800
#
# Epoch 00081: accuracy did not improve from 0.95250
# Epoch 82/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.2978 - accuracy: 0.9400 - val_loss: 2.2429 - val_accuracy: 0.5350
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00082: accuracy did not improve from 0.95250
# Epoch 83/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.2761 - accuracy: 0.9475 - val_loss: 1.6154 - val_accuracy: 0.6350
#
# Epoch 00083: accuracy did not improve from 0.95250
# Epoch 84/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.2480 - accuracy: 0.9663 - val_loss: 1.9832 - val_accuracy: 0.5350
#
# Epoch 00084: accuracy improved from 0.95250 to 0.96625, saving model to ./output/weights-84-0.9663.h5
# Epoch 85/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.2223 - accuracy: 0.9712 - val_loss: 1.8190 - val_accuracy: 0.5700
#
# Epoch 00085: accuracy improved from 0.96625 to 0.97125, saving model to ./output/weights-85-0.9712.h5
# Epoch 86/200
# 20/20 [==============================] - 4s 198ms/step - loss: 0.2224 - accuracy: 0.9725 - val_loss: 2.0491 - val_accuracy: 0.5750
#
# Epoch 00086: accuracy improved from 0.97125 to 0.97250, saving model to ./output/weights-86-0.9725.h5
# Epoch 87/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.2104 - accuracy: 0.9712 - val_loss: 2.4383 - val_accuracy: 0.4900
#
# Epoch 00087: accuracy did not improve from 0.97250
# Epoch 88/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.2040 - accuracy: 0.9800 - val_loss: 2.0128 - val_accuracy: 0.5250
#
# Epoch 00088: accuracy improved from 0.97250 to 0.98000, saving model to ./output/weights-88-0.9800.h5
# Epoch 89/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1908 - accuracy: 0.9800 - val_loss: 2.3080 - val_accuracy: 0.5000
#
# Epoch 00089: accuracy did not improve from 0.98000
# Epoch 90/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.2012 - accuracy: 0.9725 - val_loss: 1.8610 - val_accuracy: 0.5300
#
# Epoch 00090: accuracy did not improve from 0.98000
# Epoch 91/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.2127 - accuracy: 0.9700 - val_loss: 1.7143 - val_accuracy: 0.6050
#
# Epoch 00091: accuracy did not improve from 0.98000
# Epoch 92/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1952 - accuracy: 0.9775 - val_loss: 1.8943 - val_accuracy: 0.5750
#
# Epoch 00092: accuracy did not improve from 0.98000
# Epoch 93/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.2039 - accuracy: 0.9750 - val_loss: 1.8403 - val_accuracy: 0.6050
#
# Epoch 00093: accuracy did not improve from 0.98000
# Epoch 94/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.1807 - accuracy: 0.9850 - val_loss: 1.7296 - val_accuracy: 0.5950
#
# Epoch 00094: accuracy improved from 0.98000 to 0.98500, saving model to ./output/weights-94-0.9850.h5
# Epoch 95/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.2031 - accuracy: 0.9775 - val_loss: 1.9843 - val_accuracy: 0.5750
#
# Epoch 00095: accuracy did not improve from 0.98500
# Epoch 96/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1913 - accuracy: 0.9800 - val_loss: 1.7625 - val_accuracy: 0.6200
#
# Epoch 00096: accuracy did not improve from 0.98500
# Epoch 97/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1772 - accuracy: 0.9850 - val_loss: 1.5603 - val_accuracy: 0.6900
#
# Epoch 00097: accuracy did not improve from 0.98500
# Epoch 98/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1821 - accuracy: 0.9812 - val_loss: 1.6936 - val_accuracy: 0.6550
#
# Epoch 00098: accuracy did not improve from 0.98500
# Epoch 99/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.2212 - accuracy: 0.9663 - val_loss: 2.1101 - val_accuracy: 0.5500
#
# Epoch 00099: accuracy did not improve from 0.98500
# Epoch 100/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1935 - accuracy: 0.9762 - val_loss: 2.3474 - val_accuracy: 0.5050
#
# Epoch 00100: accuracy did not improve from 0.98500
# Epoch 101/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1935 - accuracy: 0.9787 - val_loss: 1.7773 - val_accuracy: 0.6050
#
# Epoch 00101: accuracy did not improve from 0.98500
# Epoch 102/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1860 - accuracy: 0.9812 - val_loss: 1.8003 - val_accuracy: 0.5850
#
# Epoch 00102: accuracy did not improve from 0.98500
# Epoch 103/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1854 - accuracy: 0.9837 - val_loss: 1.9749 - val_accuracy: 0.5500
#
# Epoch 00103: accuracy did not improve from 0.98500
# Epoch 104/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.2258 - accuracy: 0.9688 - val_loss: 1.9192 - val_accuracy: 0.5600
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00104: accuracy did not improve from 0.98500
# Epoch 105/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1940 - accuracy: 0.9775 - val_loss: 1.8521 - val_accuracy: 0.5600
#
# Epoch 00105: accuracy did not improve from 0.98500
# Epoch 106/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1741 - accuracy: 0.9837 - val_loss: 1.9277 - val_accuracy: 0.5450
#
# Epoch 00106: accuracy did not improve from 0.98500
# Epoch 107/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1667 - accuracy: 0.9862 - val_loss: 1.8098 - val_accuracy: 0.5650
#
# Epoch 00107: accuracy improved from 0.98500 to 0.98625, saving model to ./output/weights-107-0.9862.h5
# Epoch 108/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1715 - accuracy: 0.9875 - val_loss: 1.9243 - val_accuracy: 0.5550
#
# Epoch 00108: accuracy improved from 0.98625 to 0.98750, saving model to ./output/weights-108-0.9875.h5
# Epoch 109/200
# 20/20 [==============================] - 4s 205ms/step - loss: 0.1614 - accuracy: 0.9887 - val_loss: 2.1336 - val_accuracy: 0.5400
#
# Epoch 00109: accuracy improved from 0.98750 to 0.98875, saving model to ./output/weights-109-0.9887.h5
# Epoch 110/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1567 - accuracy: 0.9887 - val_loss: 2.0716 - val_accuracy: 0.5550
#
# Epoch 00110: accuracy did not improve from 0.98875
# Epoch 111/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1590 - accuracy: 0.9912 - val_loss: 2.0425 - val_accuracy: 0.5800
#
# Epoch 00111: accuracy improved from 0.98875 to 0.99125, saving model to ./output/weights-111-0.9912.h5
# Epoch 112/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1683 - accuracy: 0.9875 - val_loss: 2.0575 - val_accuracy: 0.5450
#
# Epoch 00112: accuracy did not improve from 0.99125
# Epoch 113/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.1610 - accuracy: 0.9925 - val_loss: 1.8889 - val_accuracy: 0.5950
#
# Epoch 00113: accuracy improved from 0.99125 to 0.99250, saving model to ./output/weights-113-0.9925.h5
# Epoch 114/200
# 20/20 [==============================] - 4s 205ms/step - loss: 0.1595 - accuracy: 0.9900 - val_loss: 2.0530 - val_accuracy: 0.5400
#
# Epoch 00114: accuracy did not improve from 0.99250
# Epoch 115/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1729 - accuracy: 0.9837 - val_loss: 2.0636 - val_accuracy: 0.5450
#
# Epoch 00115: accuracy did not improve from 0.99250
# Epoch 116/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1545 - accuracy: 0.9937 - val_loss: 1.8974 - val_accuracy: 0.5650
#
# Epoch 00116: accuracy improved from 0.99250 to 0.99375, saving model to ./output/weights-116-0.9937.h5
# Epoch 117/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1718 - accuracy: 0.9875 - val_loss: 1.9198 - val_accuracy: 0.5550
#
# Epoch 00117: accuracy did not improve from 0.99375
# Epoch 118/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1579 - accuracy: 0.9925 - val_loss: 1.8325 - val_accuracy: 0.5950
#
# Epoch 00118: accuracy did not improve from 0.99375
# Epoch 119/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1517 - accuracy: 0.9937 - val_loss: 1.9597 - val_accuracy: 0.5600
#
# Epoch 00119: accuracy did not improve from 0.99375
# Epoch 120/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1579 - accuracy: 0.9862 - val_loss: 2.0335 - val_accuracy: 0.5600
#
# Epoch 00120: accuracy did not improve from 0.99375
# Epoch 121/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1589 - accuracy: 0.9925 - val_loss: 1.9211 - val_accuracy: 0.5600
#
# Epoch 00121: accuracy did not improve from 0.99375
# Epoch 122/200
# 20/20 [==============================] - 4s 209ms/step - loss: 0.1765 - accuracy: 0.9837 - val_loss: 1.8019 - val_accuracy: 0.6000
#
# Epoch 00122: accuracy did not improve from 0.99375
# Epoch 123/200
# 20/20 [==============================] - 4s 209ms/step - loss: 0.1655 - accuracy: 0.9862 - val_loss: 1.9697 - val_accuracy: 0.5900
#
# Epoch 00123: accuracy did not improve from 0.99375
# Epoch 124/200
# 20/20 [==============================] - 4s 206ms/step - loss: 0.1621 - accuracy: 0.9875 - val_loss: 2.0113 - val_accuracy: 0.5600
#
# Epoch 00124: accuracy did not improve from 0.99375
# Epoch 125/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1626 - accuracy: 0.9812 - val_loss: 2.0184 - val_accuracy: 0.5650
#
# Epoch 00125: accuracy did not improve from 0.99375
# Epoch 126/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.1735 - accuracy: 0.9837 - val_loss: 2.1479 - val_accuracy: 0.5200
#
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00126: accuracy did not improve from 0.99375
# Epoch 127/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1619 - accuracy: 0.9850 - val_loss: 1.9869 - val_accuracy: 0.5600
#
# Epoch 00127: accuracy did not improve from 0.99375
# Epoch 128/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1527 - accuracy: 0.9912 - val_loss: 1.9565 - val_accuracy: 0.5950
#
# Epoch 00128: accuracy did not improve from 0.99375
# Epoch 129/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1627 - accuracy: 0.9850 - val_loss: 1.9040 - val_accuracy: 0.5900
#
# Epoch 00129: accuracy did not improve from 0.99375
# Epoch 130/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1541 - accuracy: 0.9925 - val_loss: 1.9606 - val_accuracy: 0.5650
#
# Epoch 00130: accuracy did not improve from 0.99375
# Epoch 131/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1443 - accuracy: 0.9900 - val_loss: 1.8945 - val_accuracy: 0.5700
#
# Epoch 00131: accuracy did not improve from 0.99375
# Epoch 132/200
# 20/20 [==============================] - 4s 205ms/step - loss: 0.1464 - accuracy: 0.9925 - val_loss: 1.8460 - val_accuracy: 0.5750
#
# Epoch 00132: accuracy did not improve from 0.99375
# Epoch 133/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1457 - accuracy: 0.9950 - val_loss: 1.7475 - val_accuracy: 0.6150
#
# Epoch 00133: accuracy improved from 0.99375 to 0.99500, saving model to ./output/weights-133-0.9950.h5
# Epoch 134/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1656 - accuracy: 0.9887 - val_loss: 1.8468 - val_accuracy: 0.5950
#
# Epoch 00134: accuracy did not improve from 0.99500
# Epoch 135/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1449 - accuracy: 0.9925 - val_loss: 1.9379 - val_accuracy: 0.5800
#
# Epoch 00135: accuracy did not improve from 0.99500
# Epoch 136/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1552 - accuracy: 0.9862 - val_loss: 1.8866 - val_accuracy: 0.6050
#
# Epoch 00136: accuracy did not improve from 0.99500
# Epoch 137/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1431 - accuracy: 0.9937 - val_loss: 1.8187 - val_accuracy: 0.6150
#
# Epoch 00137: accuracy did not improve from 0.99500
# Epoch 138/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1464 - accuracy: 0.9937 - val_loss: 1.8419 - val_accuracy: 0.5850
#
# Epoch 00138: accuracy did not improve from 0.99500
# Epoch 139/200
# 20/20 [==============================] - 4s 198ms/step - loss: 0.1471 - accuracy: 0.9925 - val_loss: 1.8610 - val_accuracy: 0.5850
#
# Epoch 00139: accuracy did not improve from 0.99500
# Epoch 140/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1559 - accuracy: 0.9900 - val_loss: 1.8816 - val_accuracy: 0.5800
#
# Epoch 00140: accuracy did not improve from 0.99500
# Epoch 141/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1518 - accuracy: 0.9912 - val_loss: 1.8240 - val_accuracy: 0.5750
#
# Epoch 00141: accuracy did not improve from 0.99500
# Epoch 142/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1412 - accuracy: 0.9950 - val_loss: 1.7701 - val_accuracy: 0.5900
#
# Epoch 00142: accuracy did not improve from 0.99500
# Epoch 143/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1409 - accuracy: 0.9937 - val_loss: 1.8477 - val_accuracy: 0.5800
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00143: accuracy did not improve from 0.99500
# Epoch 144/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1406 - accuracy: 0.9950 - val_loss: 1.9317 - val_accuracy: 0.5850
#
# Epoch 00144: accuracy did not improve from 0.99500
# Epoch 145/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1550 - accuracy: 0.9887 - val_loss: 1.8791 - val_accuracy: 0.5900
#
# Epoch 00145: accuracy did not improve from 0.99500
# Epoch 146/200
# 20/20 [==============================] - 4s 207ms/step - loss: 0.1557 - accuracy: 0.9900 - val_loss: 1.8613 - val_accuracy: 0.5800
#
# Epoch 00146: accuracy did not improve from 0.99500
# Epoch 147/200
# 20/20 [==============================] - 4s 206ms/step - loss: 0.1363 - accuracy: 0.9950 - val_loss: 1.8078 - val_accuracy: 0.6050
#
# Epoch 00147: accuracy did not improve from 0.99500
# Epoch 148/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1414 - accuracy: 0.9950 - val_loss: 1.7510 - val_accuracy: 0.6100
#
# Epoch 00148: accuracy did not improve from 0.99500
# Epoch 149/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1390 - accuracy: 0.9937 - val_loss: 1.7431 - val_accuracy: 0.6200
#
# Epoch 00149: accuracy did not improve from 0.99500
# Epoch 150/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1533 - accuracy: 0.9875 - val_loss: 1.8135 - val_accuracy: 0.5950
#
# Epoch 00150: accuracy did not improve from 0.99500
# Epoch 151/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.1442 - accuracy: 0.9912 - val_loss: 1.9331 - val_accuracy: 0.5750
#
# Epoch 00151: accuracy did not improve from 0.99500
# Epoch 152/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1482 - accuracy: 0.9937 - val_loss: 1.9020 - val_accuracy: 0.5800
#
# Epoch 00152: accuracy did not improve from 0.99500
# Epoch 153/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1497 - accuracy: 0.9900 - val_loss: 1.8540 - val_accuracy: 0.5900
#
# Epoch 00153: accuracy did not improve from 0.99500
# Epoch 154/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1441 - accuracy: 0.9925 - val_loss: 1.8704 - val_accuracy: 0.5950
#
# Epoch 00154: accuracy did not improve from 0.99500
# Epoch 155/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1439 - accuracy: 0.9925 - val_loss: 1.8863 - val_accuracy: 0.5800
#
# Epoch 00155: accuracy did not improve from 0.99500
# Epoch 156/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1487 - accuracy: 0.9912 - val_loss: 1.8866 - val_accuracy: 0.5950
#
# Epoch 00156: accuracy did not improve from 0.99500
# Epoch 157/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1501 - accuracy: 0.9900 - val_loss: 1.8074 - val_accuracy: 0.6050
#
# Epoch 00157: accuracy did not improve from 0.99500
# Epoch 158/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1457 - accuracy: 0.9887 - val_loss: 1.8006 - val_accuracy: 0.6150
#
# Epoch 00158: accuracy did not improve from 0.99500
# Epoch 159/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1409 - accuracy: 0.9962 - val_loss: 1.7929 - val_accuracy: 0.6300
#
# Epoch 00159: accuracy improved from 0.99500 to 0.99625, saving model to ./output/weights-159-0.9962.h5
# Epoch 160/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1395 - accuracy: 0.9925 - val_loss: 1.7968 - val_accuracy: 0.6050
#
# Epoch 00160: accuracy did not improve from 0.99625
# Epoch 161/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1486 - accuracy: 0.9925 - val_loss: 1.8853 - val_accuracy: 0.5950
#
# Epoch 00161: accuracy did not improve from 0.99625
# Epoch 162/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1370 - accuracy: 0.9950 - val_loss: 1.8996 - val_accuracy: 0.5950
#
# Epoch 00162: accuracy did not improve from 0.99625
# Epoch 163/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1497 - accuracy: 0.9900 - val_loss: 1.7635 - val_accuracy: 0.6200
#
# Epoch 00163: accuracy did not improve from 0.99625
# Epoch 164/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1382 - accuracy: 0.9950 - val_loss: 1.7501 - val_accuracy: 0.6200
#
# Epoch 00164: accuracy did not improve from 0.99625
# Epoch 165/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1439 - accuracy: 0.9912 - val_loss: 1.7940 - val_accuracy: 0.6000
#
# Epoch 00165: accuracy did not improve from 0.99625
# Epoch 166/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1340 - accuracy: 0.9975 - val_loss: 1.7540 - val_accuracy: 0.6050
#
# Epoch 00166: accuracy improved from 0.99625 to 0.99750, saving model to ./output/weights-166-0.9975.h5
# Epoch 167/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1485 - accuracy: 0.9887 - val_loss: 1.7553 - val_accuracy: 0.6150
#
# Epoch 00167: accuracy did not improve from 0.99750
# Epoch 168/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1474 - accuracy: 0.9887 - val_loss: 1.7872 - val_accuracy: 0.5900
#
# Epoch 00168: accuracy did not improve from 0.99750
# Epoch 169/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1415 - accuracy: 0.9925 - val_loss: 1.8394 - val_accuracy: 0.5700
#
# Epoch 00169: accuracy did not improve from 0.99750
# Epoch 170/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1440 - accuracy: 0.9912 - val_loss: 1.8129 - val_accuracy: 0.5600
#
# Epoch 00170: accuracy did not improve from 0.99750
# Epoch 171/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1419 - accuracy: 0.9950 - val_loss: 1.8263 - val_accuracy: 0.5550
#
# Epoch 00171: accuracy did not improve from 0.99750
# Epoch 172/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1432 - accuracy: 0.9950 - val_loss: 1.8600 - val_accuracy: 0.5600
#
# Epoch 00172: accuracy did not improve from 0.99750
# Epoch 173/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1577 - accuracy: 0.9862 - val_loss: 1.9307 - val_accuracy: 0.5900
#
# Epoch 00173: accuracy did not improve from 0.99750
# Epoch 174/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1432 - accuracy: 0.9925 - val_loss: 1.9213 - val_accuracy: 0.5700
#
# Epoch 00174: accuracy did not improve from 0.99750
# Epoch 175/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1376 - accuracy: 0.9950 - val_loss: 1.9370 - val_accuracy: 0.5700
#
# Epoch 00175: accuracy did not improve from 0.99750
# Epoch 176/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1479 - accuracy: 0.9900 - val_loss: 1.8647 - val_accuracy: 0.5850
#
# Epoch 00176: accuracy did not improve from 0.99750
# Epoch 177/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1378 - accuracy: 0.9925 - val_loss: 1.8654 - val_accuracy: 0.6100
#
# Epoch 00177: accuracy did not improve from 0.99750
# Epoch 178/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1458 - accuracy: 0.9900 - val_loss: 1.8910 - val_accuracy: 0.6050
#
# Epoch 00178: accuracy did not improve from 0.99750
# Epoch 179/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1440 - accuracy: 0.9912 - val_loss: 1.8921 - val_accuracy: 0.6000
#
# Epoch 00179: accuracy did not improve from 0.99750
# Epoch 180/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1401 - accuracy: 0.9937 - val_loss: 1.8336 - val_accuracy: 0.6150
#
# Epoch 00180: accuracy did not improve from 0.99750
# Epoch 181/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1446 - accuracy: 0.9937 - val_loss: 1.8589 - val_accuracy: 0.6050
#
# Epoch 00181: accuracy did not improve from 0.99750
# Epoch 182/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1348 - accuracy: 0.9950 - val_loss: 1.8494 - val_accuracy: 0.6000
#
# Epoch 00182: accuracy did not improve from 0.99750
# Epoch 183/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1309 - accuracy: 0.9975 - val_loss: 1.8272 - val_accuracy: 0.6150
#
# Epoch 00183: accuracy did not improve from 0.99750
# Epoch 184/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1327 - accuracy: 0.9950 - val_loss: 1.8282 - val_accuracy: 0.6250
#
# Epoch 00184: accuracy did not improve from 0.99750
# Epoch 185/200
# 20/20 [==============================] - 4s 199ms/step - loss: 0.1367 - accuracy: 0.9950 - val_loss: 1.8563 - val_accuracy: 0.6150
#
# Epoch 00185: accuracy did not improve from 0.99750
# Epoch 186/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1586 - accuracy: 0.9875 - val_loss: 1.8612 - val_accuracy: 0.6200
#
# Epoch 00186: accuracy did not improve from 0.99750
# Epoch 187/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1418 - accuracy: 0.9937 - val_loss: 1.9085 - val_accuracy: 0.6050
#
# Epoch 00187: accuracy did not improve from 0.99750
# Epoch 188/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1335 - accuracy: 0.9962 - val_loss: 1.9106 - val_accuracy: 0.5950
#
# Epoch 00188: accuracy did not improve from 0.99750
# Epoch 189/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1414 - accuracy: 0.9937 - val_loss: 1.8584 - val_accuracy: 0.6150
#
# Epoch 00189: accuracy did not improve from 0.99750
# Epoch 190/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1406 - accuracy: 0.9887 - val_loss: 1.8050 - val_accuracy: 0.6350
#
# Epoch 00190: accuracy did not improve from 0.99750
# Epoch 191/200
# 20/20 [==============================] - 4s 204ms/step - loss: 0.1382 - accuracy: 0.9937 - val_loss: 1.8099 - val_accuracy: 0.6150
#
# Epoch 00191: accuracy did not improve from 0.99750
# Epoch 192/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1338 - accuracy: 0.9950 - val_loss: 1.8791 - val_accuracy: 0.6000
#
# Epoch 00192: accuracy did not improve from 0.99750
# Epoch 193/200
# 20/20 [==============================] - 4s 200ms/step - loss: 0.1423 - accuracy: 0.9912 - val_loss: 1.8852 - val_accuracy: 0.5900
#
# Epoch 00193: accuracy did not improve from 0.99750
# Epoch 194/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1296 - accuracy: 0.9975 - val_loss: 1.9264 - val_accuracy: 0.5850
#
# Epoch 00194: accuracy did not improve from 0.99750
# Epoch 195/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1496 - accuracy: 0.9862 - val_loss: 1.9550 - val_accuracy: 0.5650
#
# Epoch 00195: accuracy did not improve from 0.99750
# Epoch 196/200
# 20/20 [==============================] - 4s 201ms/step - loss: 0.1410 - accuracy: 0.9912 - val_loss: 1.8596 - val_accuracy: 0.6100
#
# Epoch 00196: accuracy did not improve from 0.99750
# Epoch 197/200
# 20/20 [==============================] - 4s 202ms/step - loss: 0.1459 - accuracy: 0.9887 - val_loss: 1.8844 - val_accuracy: 0.5750
#
# Epoch 00197: accuracy did not improve from 0.99750
# Epoch 198/200
# 20/20 [==============================] - 4s 203ms/step - loss: 0.1301 - accuracy: 0.9962 - val_loss: 1.8737 - val_accuracy: 0.5900
#
# Epoch 00198: accuracy did not improve from 0.99750
# Epoch 199/200
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1330 - accuracy: 0.9950 - val_loss: 1.8530 - val_accuracy: 0.5900
#
# Epoch 00199: accuracy did not improve from 0.99750
# Epoch 200/200
# 20/20 [==============================] - 4s 208ms/step - loss: 0.1274 - accuracy: 0.9975 - val_loss: 1.8741 - val_accuracy: 0.5800
#
# Epoch 00200: accuracy did not improve from 0.99750

# %%
model.load_weights("././output/weights-166-0.9975.h5")# Got 99.75 accuracy on training data

# %%
#Model Evaluation
model.evaluate(test_set,
        steps=test_set.n//test_set.batch_size,verbose=1)#OUTPUT
# Out:
# 5/5 [==============================] - 1s 152ms/step - loss: 1.7540 - accuracy: 0.6050
# [1.7539807558059692, 0.6050000190734863]

# %%
pred = model.predict(test_set, steps=test_set.n//test_set.batch_size, verbose=1)
# Out:
# 5/5 [==============================] - 1s 147ms/step

# %%
predicted_class_indices=np.argmax(pred,axis=1)

labels = (training_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
predictions = predictions[:200]
filenames=test_set.filenames

# %%
print(len(filenames), len(predictions))
# (200, 200)
# Out:
# 200 200

# %%
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})
results.to_csv("Music_Genres_prediction_CNN.csv",index=False)
